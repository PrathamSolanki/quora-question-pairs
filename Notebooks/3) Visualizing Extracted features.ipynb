# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_df = pd.read_pickle('dataframe_toverify')

# %% [markdown]
# ## 1) Unigrams

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x="is_duplicate", y="unigrams_common_count", data=train_df)
plt.xlabel('Is duplicate', fontsize=12)
plt.ylabel('Unigrams common count', fontsize=12)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x="is_duplicate", y="unigrams_common_ratio", data=train_df)
plt.xlabel('Is duplicate', fontsize=12)
plt.ylabel('Unigrams common ratio', fontsize=12)
plt.show()

# %% [markdown]
# ## 2) Bigrams

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x="is_duplicate", y="bigrams_common_count", data=train_df)
plt.xlabel('Is duplicate', fontsize=12)
plt.ylabel('Bigrams common count', fontsize=12)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x="is_duplicate", y="bigrams_common_ratio", data=train_df)
plt.xlabel('Is duplicate', fontsize=12)
plt.ylabel('Bigrams common ratio', fontsize=12)
plt.show()

# %% [markdown]
# ## 3) Trigrams

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x="is_duplicate", y="trigrams_common_count", data=train_df)
plt.xlabel('Is duplicate', fontsize=12)
plt.ylabel('Trigrams common count', fontsize=12)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x="is_duplicate", y="trigrams_common_ratio", data=train_df)
plt.xlabel('Is duplicate', fontsize=12)
plt.ylabel('Trigrams common ratio', fontsize=12)
plt.show()

# %% [markdown]
# ## 4) Nouns

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x="is_duplicate", y="nouns_common_count", data=train_df)
plt.xlabel('Is duplicate', fontsize=12)
plt.ylabel('Nouns common count', fontsize=12)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x="is_duplicate", y="nouns_common_ratio", data=train_df)
plt.xlabel('Is duplicate', fontsize=12)
plt.ylabel('Nouns common ratio', fontsize=12)
plt.show()

# %% [markdown]
# ## 5) Adjectives

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x="is_duplicate", y="adjectives_common_count", data=train_df)
plt.xlabel('Is duplicate', fontsize=12)
plt.ylabel('Adjectives common count', fontsize=12)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x="is_duplicate", y="adjectives_common_ratio", data=train_df)
plt.xlabel('Is duplicate', fontsize=12)
plt.ylabel('Adjectives common ratio', fontsize=12)
plt.show()

# %% [markdown]
# ## 6) Verbs

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x="is_duplicate", y="verbs_common_count", data=train_df)
plt.xlabel('Is duplicate', fontsize=12)
plt.ylabel('Verbs common count', fontsize=12)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x="is_duplicate", y="verbs_common_ratio", data=train_df)
plt.xlabel('Is duplicate', fontsize=12)
plt.ylabel('Verbs common ratio', fontsize=12)
plt.show()

# %% [markdown]
# ## 7) Words match

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x="is_duplicate", y="word_match", data=train_df)
plt.xlabel('Is duplicate', fontsize=12)
plt.ylabel('Words match', fontsize=12)
plt.show()

# %% [markdown]
# ## 8) tf-idf Words match

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x="is_duplicate", y="tfidf_train_word_match", data=train_df)
plt.xlabel('Is duplicate', fontsize=12)
plt.ylabel('tf- idf Words match', fontsize=12)
plt.show()
